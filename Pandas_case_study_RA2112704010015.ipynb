# %%
pip install pandas

# %%
pip install numpy

# %%
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
p1 = '/content/drive/MyDrive/Colab Notebooks/googleplaystore.csv'
data = pd.read_csv(p1)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# To display first n rows of data
n = int(input("Enter number of top rows to be viewed:--")) 
data.head(n)
# Out:
# Enter number of top rows to be viewed:--10
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
# 5                         Paper flowers instructions  ...    2.3 and up
# 6            Smoke Effect Photo Maker - Smoke Editor  ...  4.0.3 and up
# 7                                   Infinite Painter  ...    4.2 and up
# 8                               Garden Coloring Book  ...    3.0 and up
# 9                      Kids Paint Free - Drawing Fun  ...  4.0.3 and up
#
# [10 rows x 13 columns]

# %%
#To display the last n rows of dataset
l = int(input("Enter number of top rows to be viewed:--"))
data.tail(l)

# %%
#To display Shape of dataset
print("Number of Rows:--",data.shape[0])
print("Number of Columns:--",data.shape[1])

# %%
#To get information about dataset
data.info
# Out:
# <bound method DataFrame.info of                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# ...

# %%
#Get overall statisics about the Dataframe
data.describe(include='all')
# Out:
#            App Category  ...         Current Ver Android Ver
# count    10841    10841  ...               10833       10838
# unique    9660       34  ...                2832          33
# top     ROBLOX   FAMILY  ...  Varies with device  4.1 and up
# freq         9     1972  ...                1459        2451
# mean       NaN      NaN  ...                 NaN         NaN
# std        NaN      NaN  ...                 NaN         NaN
# min        NaN      NaN  ...                 NaN         NaN
# 25%        NaN      NaN  ...                 NaN         NaN
# 50%        NaN      NaN  ...                 NaN         NaN
# 75%        NaN      NaN  ...                 NaN         NaN
# max        NaN      NaN  ...                 NaN         NaN
#
# [11 rows x 13 columns]

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
#Total Number of App Titles contain Astrology
l=len(data[data['App'].str.contains('Astrology',case = True)])
print(l)
# Out:
# 3

# %%
# Average App Rating
print(data['Rating'].mean())
# Out:
# 4.193338315362448

# %%
#Total Number of Unique category
print(data['Category'].nunique())
# Out:
# 34

# %%
#Category getting highest average rating
print(data.groupby('Category')['Rating'].mean().sort_values(ascending=False))
# Out:
# Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ENTERTAINMENT           4.126174
# BUSINESS                4.121452
# ...

# %%
#Find total number of Apps having 5 Star rating
star_5=len(data[data['Rating']==5.0])
print(star_5)
# Out:
# 274

# %%
# Find average Value of Reviews
data['Reviews']=data['Reviews'].replace('3.0M',3.0)
data['Reviews']=data['Reviews'].astype('float')
n_reviews=data['Reviews'].mean()
print(n_reviews)
# Out:
# 444111.9265750392

# %%
#Find Total Number of free and paid Apps
paid = data['Type'].value_counts()
print(paid)
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %%
#App having max reviews
max_review_app=data[data['Reviews'].max()==data['Reviews']]['App']
print(max_review_app)
# Out:
# 2544    Facebook
# Name: App, dtype: object

# %%
#Diaplay Top 5 apps having Highest Reviews
index = data['Reviews'].sort_values(ascending=False).head().index
print(data.iloc[index]['App'])
# Out:
# 2989               GollerCepte Live Score
# 4970         Ad Block REMOVER - NEED ROOT
# 2705                  SnipSnap Coupon App
# 2723                  SnipSnap Coupon App
# 3049    US Open Tennis Championships 2018
# Name: App, dtype: object

# %%
#Find Average Rating of free and paid Apps
data.groupby('Type')['Rating'].mean()
# Out:
# Type
# 0       19.000000
# Free     4.186203
# Paid     4.266615
# Name: Rating, dtype: float64

# %%
#Display top 5 Apps Having Maximun Installs
data['Install_1'] = data['Installs'].str.replace(',','')
data['Install_1'] = data['Install_1'].str.replace('+','')
data['Install_1'] = data['Install_1'].str.replace('Free','0')
data['Install_1'] = data['Install_1'].astype('int')
index_installs = data['Install_1'].sort_values(ascending=False).head().index
print(data.iloc[index_installs]['App'])
# Out:
# 4096                Gmail
# 3234               Google
# 2554              Google+
# 3565         Google Drive
# 865     Google Play Games
# Name: App, dtype: object
